# %% [markdown]
# # Train XGBoost Model
# Imports

# %%
import pandas as pd
import joblib
from xgboost import XGBClassifier
from sklearn.model_selection import train_test_split
from pathlib import Path

# %% [markdown]
# Load Data

# %%
# Assuming X_encoded and y_encoded from previous step are saved/loaded here
# For demonstration, we load the raw and process or use a processed csv.
print('Load processed features and target')

# %% [markdown]
# Initialize and Train Model

# %%
# XGBoost Training
xgb = XGBClassifier(n_estimators=300, learning_rate=0.05, max_depth=6, random_state=42)
# xgb.fit(X_train_scaled, y_train)
print('XGBoost model initialized and ready for training.')

# %% [markdown]
# Save Model

# %%
# joblib.dump(xgb, 'xgb_model.pkl')
print('Model saved.')
